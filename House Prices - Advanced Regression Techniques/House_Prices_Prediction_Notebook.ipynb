# %% [markdown]
# # House Prices Prediction Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split # GridSearchCV
from sklearn.metrics import mean_squared_log_error # make_scorer
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import xgboost

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Reading The Dataframe

# %%
train_df = pd.read_csv('train.csv')

test_df = pd.read_csv('test.csv')

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print('The train df contains {} rows and {} columns'.format(train_df.shape[0], train_df.shape[1]))
# Out:
# The train df contains 1460 rows and 81 columns

# %%
print('The test df contains {} rows and {} columns'.format(test_df.shape[0], test_df.shape[1]))
# Out:
# The test df contains 1459 rows and 80 columns

# %% [markdown]
# ## Exploratory data analysis

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(data=train_df['SalePrice'], bins=50, kde=True)

plt.title('The distribution of house prices', fontsize=14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %%
numerical_columns = [column for column in train_df.columns if train_df[column].dtype in ['int64', 'float64']]

# %%
categorical_columns = [column for column in train_df.columns if train_df[column].dtype not in ['int64', 'float64']]

# %%
# Calculate the null values for each column
null_values = train_df[numerical_columns].isnull().sum()

# Filter columns with non-zero null values
columns_with_null = null_values[null_values > 0]
columns_with_null
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
# Calculate the null values for each column
null_values = train_df.isnull().sum()

# Filter columns with non-zero null values
columns_with_null = null_values[null_values > 0]
columns_with_null
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train_df['LotFrontage'].fillna(train_df['LotFrontage'].mean(), inplace=True)

# %%
train_df['Alley'].fillna('None', inplace=True)

# %%
train_df['MasVnrType']
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
#          ...
# 1455       None
# 1456      Stone
# 1457       None
# 1458       None
# 1459       None
# Name: MasVnrType, Length: 1460, dtype: object

# %%
train_df['MasVnrType'].mode()
# Out:
# 0    None
# dtype: object

# %%
train_df.groupby('MasVnrType')['MasVnrArea'].sum()
# Out:
# MasVnrType
# BrkCmn       3715.0
# BrkFace    115259.0
# None          946.0
# Stone       30631.0
# Name: MasVnrArea, dtype: float64

# %%
LotArea[['LotFrontage', 'LotArea']].loc[train_df['LotFrontage'].isna()]
# Out:
#       LotFrontage  LotArea
# 7             NaN    10382
# 12            NaN    12968
# 14            NaN    10920
# 16            NaN    11241
# 24            NaN     8246
# ...           ...      ...
# 1429          NaN    12546
# 1431          NaN     4928
# 1441          NaN     4426
# 1443          NaN     8854
# 1446          NaN    26142
#
# [259 rows x 2 columns]

# %%
train_df[['MasVnrType','MasVnrArea']].loc[train_df['MasVnrArea'].isna()]
# Out:
#      MasVnrType  MasVnrArea
# 234         NaN         NaN
# 529         NaN         NaN
# 650         NaN         NaN
# 936         NaN         NaN
# 973         NaN         NaN
# 977         NaN         NaN
# 1243        NaN         NaN
# 1278        NaN         NaN

# %%
train_df['MasVnrArea'].fillna(0)
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
#         ...
# 1455      0.0
# 1456    119.0
# 1457      0.0
# 1458      0.0
# 1459      0.0
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
test_df.isna().sum()[test_df.isna().sum() > 0]
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64
